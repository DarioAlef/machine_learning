# %%
from IPython.display import display, Markdown

md_text = """
# Pipeline Completo de Machine Learning – Dataset: California Housing

| Etapa | Objetivo | Função/Ferramenta | O que analisar/gerar | Observações |
|-------|----------|------------------|--------------------|------------|
| 1. Carregar dados | Obter o dataset | `load_housing_data()`, `pd.read_csv()` | DataFrame com todos os dados | Verificar se o CSV existe localmente ou baixar |
| 2. Visão geral | Entender estrutura inicial | `shape`, `dtypes`, `head()` | Número de linhas/colunas, tipos de colunas, primeiras linhas | Identificar features numéricas e categóricas |
| 3. Estatísticas descritivas | Medir tendências centrais e dispersão | `describe()` | Média, mediana, desvio padrão, mínimo, máximo, quartis | Detectar possíveis valores extremos e escalas diferentes |
| 4. Valores faltantes | Detectar dados incompletos | `isnull().sum()` | Quantidade de valores ausentes por coluna | Planejar imputação ou remoção de dados |
| 5. Distribuição de features | Visualizar padrões e outliers | `hist()`, `boxplot()`, `countplot()`, `sns.histplot()` | Histogramas, gráficos de caixa, contagem de categorias | Identificar assimetria, outliers e densidade de dados |
| 6. Análise de variáveis categóricas | Entender frequência e distribuição | `value_counts()`, `countplot()` | Frequência de categorias, gráficos de barras | Útil para codificação one-hot ou embeddings |
| 7. Correlação entre variáveis | Identificar relações fortes | `corr()`, `sns.heatmap()` | Matriz de correlação, correlação com a variável alvo (`median_house_value`) | Escolher features importantes para modelagem |
| 8. Relação feature-target | Avaliar impacto das features | Scatter plots, `sns.pairplot()`, `plot(kind='scatter')` | Visualizar tendências e padrões entre features e alvo | Pode revelar transformações necessárias |
| 9. Análise espacial | Visualizar padrões geográficos | `plot(kind='scatter')`, colormap, tamanho proporcional à população | Distribuição geográfica das casas, densidade populacional, valor das casas | Pode gerar insights de clustering geográfico |
| 10. Outliers | Detectar valores extremos | `boxplot()`, `describe()`, Z-score, IQR | Identificar e tratar outliers | Pode afetar regressão e escalas de features |
| 11. Feature engineering | Criar novas features informativas | Operações aritméticas (`/`, `*`), `FunctionTransformer` | `rooms_per_household`, `bedrooms_per_room`, `population_per_household` | Pode melhorar performance do modelo |
| 12. Pré-processamento | Preparar dados para modelagem | `SimpleImputer`, `StandardScaler`, `OneHotEncoder`, `Pipeline` | Dados limpos, normalizados e codificados | Essencial para evitar vieses e inconsistências |
| 13. Modelagem | Treinar modelos de regressão | `LinearRegression`, `RandomForestRegressor`, `SVR`, `MLPRegressor` | Modelos ajustados aos dados | Avaliar baseline e performance inicial |
| 14. Avaliação | Medir performance | `cross_val_score`, `mean_squared_error`, `r2_score` | RMSE, R², gráficos de erros | Permite comparação entre modelos e iteração |
| 15. Otimização de hiperparâmetros | Ajustar modelos | `GridSearchCV`, `RandomizedSearchCV` | Melhor combinação de parâmetros | Aumenta performance sem overfitting |
| 16. Persistência | Salvar modelo treinado | `joblib.dump()`, `joblib.load()` | Modelo pronto para deploy | Facilita reuso e integração |
| 17. Testes em novos dados | Previsões em dados inéditos | `predict()` | Avaliar generalização do modelo | Simula uso em produção |
| 18. Deploy | Colocar modelo em produção | Flask, FastAPI, Docker | API para previsões em tempo real | Integração com sistemas externos |
| 19. Monitoramento e feedback | Garantir performance contínua | Logs, métricas, dashboards | Detectar drift de dados ou performance | Permite retraining ou ajustes |
| 20. Retreinamento | Corrigir problemas ou melhorar performance | Reaplicar pipeline completo | Modelo atualizado | Reinicia fluxo de modelagem e avaliação, ciclo iterativo |
| 21. Projeto concluído | Quando performance está estável | - | Modelo em produção funcionando corretamente | Indica término do projeto de ML |
"""

display(Markdown(md_text))
# Out:
# # Pipeline Completo de Machine Learning – Dataset: California Housing
#
# | Etapa | Objetivo | Função/Ferramenta | O que analisar/gerar | Observações |
# |-------|----------|------------------|--------------------|------------|
# | 1. Carregar dados | Obter o dataset | `load_housing_data()`, `pd.read_csv()` | DataFrame com todos os dados | Verificar se o CSV existe localmente ou baixar |
# | 2. Visão geral | Entender estrutura inicial | `shape`, `dtypes`, `head()` | Número de linhas/colunas, tipos de colunas, primeiras linhas | Identificar features numéricas e categóricas |
# | 3. Estatísticas descritivas | Medir tendências centrais e dispersão | `describe()` | Média, mediana, desvio padrão, mínimo, máximo, quartis | Detectar possíveis valores extremos e escalas diferentes |
# | 4. Valores faltantes | Detectar dados incompletos | `isnull().sum()` | Quantidade de valores ausentes por coluna | Planejar imputação ou remoção de dados |
# ...
