# %% [markdown]
# # 1. Segmentação de Instâncias com YOLOv8
#
# ## 1.1 Objetivo
# Este notebook explora a **Segmentação de Instâncias**. Diferente da detecção de objetos simples (que apenas desenha um retângulo em volta do objeto), a segmentação identifica o contorno exato do objeto, pixel a pixel.
#
# Você aprenderá a:
# 1. Realizar inferência de segmentação em imagens e vídeos.
# 2. Acessar as máscaras binárias (a forma precisa do objeto).
# 3. Calcular a área ocupada por um objeto.
# 4. Criar efeitos visuais avançados, como remover o fundo (Color Splash).

# %% [markdown]
# ## 1.2 Detecção vs. Segmentação
# - **Detecção (Object Detection)**: Retorna coordenadas (x1, y1, x2, y2) de uma caixa. É rápido, mas inclui o fundo dentro da caixa.
# - **Segmentação (Instance Segmentation)**: Retorna uma "máscara" (polígono ou bitmap) que diz exatamente quais pixels pertencem ao objeto.

# %% [markdown]
# # 2. Primeiros Passos
#
# Vamos carregar o modelo de segmentação (`yolo11n-seg.pt`) e testá-lo em uma imagem estática.

# %%
from ultralytics import YOLO

# Carregar o modelo YOLO pré-treinado para segmentação
model = YOLO('yolo11n-seg.pt')

# Caminho da imagem (usaremos a imagem padrão do exemplo anterior ou uma nova)
source = 'amostras/image-do.jpg'

# Realizar inferência e salvar o resultado
results = model(source, save=True, conf=0.5)
# Out:
# image 1/1 c:\Users\dario\Documents\GitHub\machine_learning\aulas\03_Vision\aula_49_18-12\YOLO\amostras\image-do.jpg: 384x640 9 persons, 91.9ms
# Speed: 1.6ms preprocess, 91.9ms inference, 42.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\dario\Documents\GitHub\machine_learning\runs\segment\predict2

# %% [markdown]
# # 3. Detecção em Tempo Real (Webcam)
#
# O funcionamento básico na webcam é idêntico ao da detecção, mas o método `plot()` agora desenhará as máscaras coloridas sobre os objetos.

# %%
import cv2
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Erro ao acessar a webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)

    # Desenha as caixas E as máscaras
    annotated_frame = results[0].plot()

    cv2.imshow("YOLOv8 Segmentacao", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 persons, 1 chair, 3 laptops, 59.0ms
# Speed: 1.2ms preprocess, 59.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 4 laptops, 1 mouse, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 17.4ms
# Speed: 1.2ms preprocess, 17.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 16.1ms
# Speed: 0.9ms preprocess, 16.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 3 laptops, 1 mouse, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 4 laptops, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 21.0ms
# Speed: 1.8ms preprocess, 21.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 4 laptops, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 17.3ms
# Speed: 1.4ms preprocess, 17.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair,
9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 bottle, 1 chair, 2 laptops, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 bottle, 1 chair, 2 laptops, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 chair, 2 laptops, 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 9.1ms
# Speed: 0.9ms preprocess, 9.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 7.3ms
# Speed: 0.9ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 dining table, 2 laptops, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 dining table, 2 laptops, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 9.5ms
# Speed: 1.1ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 10.2ms
# Speed: 0.9ms preprocess, 10.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 7.9ms
# Speed: 0.9ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 8.2ms
# Speed: 1.1ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 chairs, 1 laptop, 8.4ms
# Speed: 0.9ms preprocess, 8.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 7.6ms
# Speed: 0.9ms preprocess, 7.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 8.3ms
# Speed: 0.9ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 7.5ms
# Speed: 0.8ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 8.2ms
# Speed: 1.3ms preprocess, 8.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 dining table, 3 laptops, 11.7ms
# Speed: 0.9ms preprocess, 11.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 dining table, 3 laptops, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 7.5ms
# Speed: 0.9ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 7.9ms
# Speed: 0.9ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 7.9ms
# Speed: 1.1ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 7.9ms
# Speed: 0.9ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 9.1ms
# Speed: 0.8ms preprocess, 9.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 8.5ms
# Speed: 0.8ms preprocess, 8.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 7.2ms
# Speed: 0.9ms preprocess, 7.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 dining table, 2 laptops, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 dining table, 2 laptops, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 8.8ms
# Speed: 0.9ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 7.7ms
# Speed: 0.9ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 dining table, 2 laptops, 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 2 laptops, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 dining table, 2 laptops, 7.7ms
# Speed: 0.8ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 7.6ms
# Speed: 1.1ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 dining table, 1 laptop, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops,
ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 15.7ms
# Speed: 2.7ms preprocess, 15.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 laptops, 19.3ms
# Speed: 1.5ms preprocess, 19.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 dining table, 1 laptop, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 13.9ms
# Speed: 1.7ms preprocess, 13.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 3 laptops, 15.6ms
# Speed: 1.1ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 15.3ms
# Speed: 1.3ms preprocess, 15.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 16.5ms
# Speed: 1.2ms preprocess, 16.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 8.7ms
# Speed: 0.9ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 10.9ms
# Speed: 0.9ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 laptops, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 laptops, 19.9ms
# Speed: 1.5ms preprocess, 19.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 dining table, 3 laptops, 15.7ms
# Speed: 1.6ms preprocess, 15.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 22.6ms
# Speed: 1.5ms preprocess, 22.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 1 laptop, 19.4ms
# Speed: 1.4ms preprocess, 19.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 2 laptops, 20.8ms
# Speed: 1.6ms preprocess, 20.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 17.1ms
# Speed: 1.4ms preprocess, 17.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 16.4ms
# Speed: 1.3ms preprocess, 16.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 dining table, 1 laptop, 15.3ms
# Speed: 1.3ms preprocess, 15.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 chairs, 1 dining table, 1 laptop, 17.8ms
# Speed: 1.5ms preprocess, 17.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 19.2ms
# Speed: 1.6ms preprocess, 19.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 dining table, 2 laptops, 23.6ms
# Speed: 1.9ms preprocess, 23.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 dining table, 2 laptops, 17.8ms
# Speed: 1.4ms preprocess, 17.8ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 laptops, 17.2ms
# Speed: 1.4ms preprocess, 17.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 laptops, 18.2ms
# Speed: 1.4ms preprocess, 18.2ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 3 laptops, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 3 laptops, 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 laptops, 16.1ms
# Speed: 1.3ms preprocess, 16.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 laptops, 21.1ms
# Speed: 1.9ms preprocess, 21.1ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 5 laptops, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 5 laptops, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 2 laptops, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 3 laptops, 16.9ms
# Speed: 1.6ms preprocess, 16.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 laptops, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 laptops, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 13.6ms
# Speed: 1.1ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 14.6ms
# Speed: 1.4ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 16.9ms
# Speed: 1.7ms preprocess, 16.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 9.4ms
# Speed: 0.9ms preprocess, 9.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 20.3ms
# Speed: 1.5ms preprocess, 20.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 19.0ms
# Speed: 1.5ms preprocess, 19.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 14.3ms
# Speed: 0.9ms preprocess, 14.3ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 14.2ms
# Speed: 1.3ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 16.4ms
# Speed: 1.2ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 17.1ms
# Speed: 1.5ms preprocess, 17.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 18.1ms
# Speed: 1.6ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 14.9ms
# Speed: 1.4ms preprocess, 14.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 9.8ms
# Speed: 0.8ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 13.5ms
# Speed: 1.6ms preprocess, 13.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 24.7ms
# Speed: 1.7ms preprocess, 24.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 9.5ms
# Speed: 0.9ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 9.7ms
# Speed: 1.1ms preprocess, 9.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 9.3ms
# Speed: 1.4ms preprocess, 9.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 9.0ms
# Speed: 0.9ms preprocess, 9.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 16.3ms
# Speed: 1.6ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 16.6ms
# Speed: 1.7ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 17.8ms
# Speed: 1.5ms preprocess, 17.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 10.9ms
# Speed: 0.8ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 10.8ms
# Speed: 0.9ms preprocess, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 24.7ms
# Speed: 1.4ms preprocess, 24.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 laptops, 12.4ms
# Speed: 0.9ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 laptops, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 9.8ms
# Speed: 0.9ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 7.9ms
# Speed: 1.1ms preprocess, 7.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 24.6ms
# Speed: 1.9ms preprocess, 24.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 18.1ms
# Speed: 1.4ms preprocess, 18.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 11.6ms
# Speed: 1.1ms preprocess, 11.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 laptops, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 18.0ms
# Speed: 1.4ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 3 laptops, 9.3ms
# Speed: 0.9ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 laptops, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 16.5ms
# ...
#
# 0: 480x640 4 persons, 1 bottle, 3 chairs, 1 laptop, 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 3 chairs, 1 laptop, 9.8ms
# Speed: 1.2ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 4 chairs, 1 laptop, 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 3 chairs, 1 laptop, 9.6ms
# Speed: 1.2ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 4 chairs, 1 laptop, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 3 chairs, 2 laptops, 9.6ms
# Speed: 1.4ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 9.6ms
# Speed: 1.2ms preprocess, 9.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 9.7ms
# Speed: 1.1ms preprocess, 9.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 3 chairs, 1 laptop, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 4 chairs, 1 laptop, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle,
 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 2 laptops, 9.4ms
# Speed: 1.2ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 2 laptops, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 2 laptops, 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 2 chairs, 1 tv, 3 laptops, 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 2 laptops, 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 3 laptops, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 3 laptops, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 tv, 2 laptops, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 2 chairs, 2 laptops, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 3 chairs, 3 laptops, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 laptop, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 10.8ms
# Speed: 1.1ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 2 laptops, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 2 laptops, 9.8ms
# Speed: 1.1ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 tv, 2 laptops, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 tv, 2 laptops, 9.6ms
# Speed: 1.1ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 3 chairs, 1 laptop, 12.0ms
# Speed: 1.3ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 tv, 1 laptop, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 4 chairs, 2 laptops, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 tv, 2 laptops, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 2 laptops, 9.6ms
# Speed: 1.2ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 3 laptops, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 tv, 1 laptop, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 chairs, 1 laptop, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 laptop, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 3 chairs, 1 laptop, 9.4ms
# Speed: 1.2ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 tv, 2 laptops, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# # 4. Aplicação Avançada 1: Cálculo de Área
#
# Como temos a máscara exata, podemos contar quantos pixels um objeto ocupa. Isso é útil para controle de qualidade industrial (ex: saber se um biscoito está do tamanho certo) ou monitoramento agrícola.
#
# O código abaixo itera sobre as máscaras e imprime a área (em pixels) de cada objeto detectado.

# %%
results = model(frame) # usando o último frame capturado

if results[0].masks is not None:
    # Itera sobre cada objeto detectado
    for i, mask in enumerate(results[0].masks.data):
        # mask é um tensor binário (0 = fundo, 1 = objeto)
        # Contamos o número de pixels não-zero
        area_pixels = mask.count_nonzero().item()
        
        # Pegamos a classe correspondente
        cls_id = int(results[0].boxes.cls[i])
        nome = model.names[cls_id]
        
        print(f"Objeto: {nome} | Área: {area_pixels} pixels")
# Out:
# 0: 480x640 3 persons, 1 bottle, 4 chairs, 1 tv, 2 laptops, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Objeto: person | Área: 65221 pixels
# Objeto: person | Área: 2091 pixels
# Objeto: person | Área: 1398 pixels
# Objeto: bottle | Área: 830 pixels
# Objeto: laptop | Área: 2299 pixels
# Objeto: chair | Área: 4655 pixels
# Objeto: chair | Área: 2310 pixels
# Objeto: laptop | Área: 1320 pixels
# Objeto: tv | Área: 1601 pixels
# Objeto: chair | Área: 2380 pixels
# Objeto: chair | Área: 1198 pixels

# %% [markdown]
# # 5. Aplicação Avançada 2: Efeito Visual (Color Splash)
#
# Vamos criar um efeito onde **todo o fundo fica em preto e branco**, e **apenas as pessoas detectadas permanecem coloridas**.
#
# ### Lógica:
# 1. Obter a máscara combinada de todas as pessoas.
# 2. Criar uma versão preto e branco (Grayscale) do frame original.
# 3. Onde a máscara for 1 (pessoa), usar o pixel colorido.
# 4. Onde a máscara for 0 (fundo), usar o pixel preto e branco.

# %%
import cv2
import numpy as np
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret: break

    # Reduzir resolução para processamento mais rápido (opcional)
    frame = cv2.resize(frame, (640, 480))
    
    # Inferência (apenas para a classe 'person', id=0)
    results = model(frame, classes=[0], verbose=False)

    # Se houver máscaras detectadas
    if results[0].masks is not None:
        # masks.data contém todas as máscaras. 
        # Somamos todas para ter uma máscara geral (alguma pessoa presente)
        # .max(0) comprime todas as detecções em uma única camada 2D
        masks_tensor = results[0].masks.data
        combined_mask = masks_tensor.max(0)[0].cpu().numpy()

        # A máscara do YOLO pode ser menor que a imagem original, redimensionamos para o tamanho do frame
        combined_mask = cv2.resize(combined_mask, (frame.shape[1], frame.shape[0]))

        # Processamento de Imagem
        # 1. Criar fundo Grayscale (convertido de volta para BGR para ter 3 canais)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        gray_bgr = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

        # 2. Binarizar a máscara (garantir 0 ou 1)
        # Pixels > 0.5 viram 1 (Objeto), outros 0 (Fundo)
        mask_binary = (combined_mask > 0.5).astype(np.uint8)
        
        # Expandir dimensões da máscara para 3 canais (para multiplicar com imagem colorida)
        mask_3ch = cv2.merge([mask_binary, mask_binary, mask_binary])

        # 3. Combinar: (Imagem Colorida * Máscara) + (Imagem PB * Máscara Invertida)
        # Parte colorida (onde mascara é 1)
        foreground = cv2.bitwise_and(frame, frame, mask=mask_binary)
        
        # Parte PB (onde mascara é 0)
        background = cv2.bitwise_and(gray_bgr, gray_bgr, mask=(1 - mask_binary))

        # Resultado final
        final_frame = cv2.add(foreground, background)
        
        cv2.imshow("Efeito Color Splash", final_frame)
    else:
        # Se não detectar ninguém, mostra apenas o frame original (ou PB, se preferir)
        cv2.imshow("Efeito Color Splash", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Conclusão
#
# ## 6.1 Resumo
# Neste notebook, vimos como a Segmentação de Instâncias nos dá um controle muito mais fino sobre os pixels da imagem. Diferente da caixa retangular, a máscara nos permite:
# - Calcular áreas precisas.
# - Recortar objetos e manipular o fundo.
# - Criar efeitos de realidade aumentada simples.
#
# ## 6.2 Próximos Passos
# - Tente inverter a lógica do Color Splash: Deixar o fundo colorido e a pessoa em preto e branco.
# - Tente substituir o fundo (background replacement) por uma imagem virtual (como em chamadas de vídeo).
