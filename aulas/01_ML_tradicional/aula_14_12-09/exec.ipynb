# %% [markdown]
# # Curvas de Aprendizado
# são gráficos de desempenho do modelo no conjunto de treinamento (train_dataset) e no conjunto de validação (test_dataset). Para gerar os gráficos, basta treinar o modelo diversas vezes em subconjuntos de tamanhos diferente do conjunto de treinamento.

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly_features.fit_transform(X)
print(x[0])
